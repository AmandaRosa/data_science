# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))
os.path.dirname(os.getcwd())
# Out:
# '/home/hiago/Projetos/Edge/git/data_science'

# %%
import numpy as np
from data_science import CompareData
from data_science.analysis_methodology import ClusterAnalysisDivergence
# Out:
# Using TensorFlow backend.

# %%
# load data (download https://1drv.ms/u/s!AuAnQXzLmsvjihFVtI28bX0y0OyW?e=dDug9Y)
data = np.load(
    "data/TESTE01/RespNoiseFiveTEST01.npy"
)
target = np.load("data/TESTE01/Targets.npy")
# get dt
dt = data[1, 0] - data[0, 0]

# remove time collum
data = data[:, 1:]

# %%
discriminators = ['rms',
 'kurtosis', 
 'peak value'
 ]

clustering = ClusterAnalysisDivergence(nominal_rotation = int( 3600/60 ), 
slice_size = 256, 
discriminators = discriminators,
normalize = 1,
nb_cluster = 4,  
clusterizer = "gaussian mixture", 
threshold = None,
size_buffer = 100,)

compare_test = CompareData(data, dt, clustering)
# Out:
# Number of samples: 3680
# 0 of 3680 samples analyzed...
# 100 of 3680 samples analyzed...
# 200 of 3680 samples analyzed...
# 300 of 3680 samples analyzed...
# 400 of 3680 samples analyzed...
# 500 of 3680 samples analyzed...
# 600 of 3680 samples analyzed...
# 700 of 3680 samples analyzed...
# 800 of 3680 samples analyzed...
# 900 of 3680 samples analyzed...
# 1000 of 3680 samples analyzed...
# 1100 of 3680 samples analyzed...
# 1200 of 3680 samples analyzed...
# 1300 of 3680 samples analyzed...
# 1400 of 3680 samples analyzed...
# 1500 of 3680 samples analyzed...
# 1600 of 3680 samples analyzed...
# 1700 of 3680 samples analyzed...
# 1800 of 3680 samples analyzed...
# 1900 of 3680 samples analyzed...
# 2000 of 3680 samples analyzed...
# 2100 of 3680 samples analyzed...
# 2200 of 3680 samples analyzed...
# 2300 of 3680 samples analyzed...
# 2400 of 3680 samples analyzed...
# 2500 of 3680 samples analyzed...
# 2600 of 3680 samples analyzed...
# 2700 of 3680 samples analyzed...
# 2800 of 3680 samples analyzed...
# 2900 of 3680 samples analyzed...
# 3000 of 3680 samples analyzed...
# 3100 of 3680 samples analyzed...
# 3200 of 3680 samples analyzed...
# 3300 of 3680 samples analyzed...
# 3400 of 3680 samples analyzed...
# 3500 of 3680 samples analyzed...
# 3600 of 3680 samples analyzed...
# 3680 of 3680 samples analyzed!

# %%
compare_test.plot(target=target)
